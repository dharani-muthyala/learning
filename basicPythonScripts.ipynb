# %%
print("Hello, Jupyter!")
# Out:
# Hello, Jupyter!

# %%
name = "sushma"
age = 16
print(name, age)
# Out:
# sushma 16

# %%
for i in range(1,10):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
def greet(name):
    return f"Hello {name}"

greet("sanju")
# Out:
# 'Hello sanju'
